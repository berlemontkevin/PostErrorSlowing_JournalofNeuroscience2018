# %% [markdown]
# # Phase Diagram Analysis

# %%
import pandas as pd
from pandas import DataFrame

import statistics as stat

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import scipy  
import scikits.bootstrap as bootstrap

# %%
clist=["0.01",
"1.0094736842105263",
"2.008947368421053",
"3.008421052631579",
"4.007894736842105",
"5.0073684210526315",
"6.006842105263158",
"7.0063157894736845",
"8.00578947368421",
"9.005263157894737",
"10.004736842105263",
"11.00421052631579",
"12.003684210526316",
"13.003157894736843",
"14.00263157894737",
"15.002105263157894",
"16.001578947368422",
"17.001052631578947",
"18.000526315789475",
"19.0"
]

#Irlist=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Ir.csv").Ir


#Irlist=['0.02',
#        '0.025714285714285714',
#        '0.03142857142857143',
 #       '0.037142857142857144',
  #      '0.04285714285714286',
   #     '0.04857142857142857',
    #    '0.054285714285714284',
     #   '0.06',
    #    '0.06571428571428571',
   #     '0.07142857142857142',
#        '0.07714285714285714',
 #       '0.08285714285714285',
  #      '0.08857142857142856',
     #   '0.09428571428571429',
      #  '0.1',
       # '0.10571428571428572',
        #'0.11142857142857143',
#        '0.11714285714285715',
 #       '0.12285714285714286',
  #      '0.12857142857142856',
   #     '0.13428571428571429',
    #    '0.14',
     #   '0.1457142857142857',
      #  '0.15142857142857144',
       # '0.15714285714285714',
#        '0.16285714285714287',
 ##       '0.16857142857142857',
   #     '0.1742857142857143',
    #    '0.18',
     #   '0.18571428571428572',
       # '0.19142857142857142',
      #  '0.19714285714285715',
#        '0.20285714285714285',
 #       '0.20857142857142857',
  #      '0.21428571428571427',
   #     '0.22',
    #    '0.2257142857142857',
     #   '0.23142857142857143',
      #  '0.23714285714285716',
       # '0.24285714285714285',
        #'0.24857142857142858',
        #'0.2542857142857143',
#'0.26',
#'0.26571428571428574',
#'0.2714285714285714',
#        '0.27714285714285714',
#        '0.28285714285714286',
#        '0.2885714285714286',
#        '0.29428571428571426',
#'0.3']
Irlist=['0.02',
        '0.025714285714285714',
"0.03",
"0.032413793103448274",
"0.03482758620689655",
"0.037241379310344824",
"0.039655172413793106",
"0.04206896551724138",
"0.04448275862068966",
"0.04689655172413793",
"0.04931034482758621",
"0.05172413793103448",
"0.05413793103448276",
"0.05655172413793103",
"0.05896551724137931",
"0.06137931034482759",
"0.06379310344827586",
"0.06620689655172414",
"0.06862068965517241",
"0.07103448275862069",
"0.07344827586206897",
"0.07586206896551724",
"0.07827586206896552",
"0.08068965517241379",
"0.08310344827586207",
"0.08551724137931034",
"0.08793103448275862",
"0.09034482758620689",
"0.09275862068965517",
"0.09517241379310344",
"0.09758620689655173",
"0.1"

]
Tr=500

# %%
def isPES(Ir,Tr,c) :
    PES=np.zeros(6)
    for i in range(1,4,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp15/Coh"+c+"-Final500Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PE = []
        PS=[]
        for j in range(1,len( df.RTs)-1,1):
            if df.LastTrial[j-1]<0:
                PE.append(df.RTs[j])
            else :
                PS.append(df.RTs[j])

         
        PES[i-1] =np.mean(PE) - np.mean(PS)
    
    for i in range(26,29,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp15/Coh"+c+"-Final500Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PE = []
        PS=[]
        for j in range(1,len( df.RTs)-1,1):
            if df.LastTrial[j-1]<0:
                PE.append(df.RTs[j])
            else :
                PS.append(df.RTs[j])

         
        PES[25-i+2] =np.mean(PE) - np.mean(PS)
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if True:#np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out


def isPIA(Ir,Tr,c) :
    PES=np.zeros(4)
    for i in range(1,3,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp15/Coh"+c+"-Final200Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE = []
        PS=[]
        for j in range(1,len( df.RTs)-1,1):
            if df.LastTrial[j-1]<0:
                PE.append(df.NotError[j])
            else :
                PS.append(df.NotError[j])

        
        PES[i-1] =np.mean(PE) - np.mean(PS)
    for i in range(26,28,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp15/Coh"+c+"-Final200Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE = []
        PS=[]
        for j in range(1,len( df.RTs)-1,1):
            if df.LastTrial[j-1]<0:
                PE.append(df.NotError[j])
            else :
                PS.append(df.NotError[j])

        
        PES[25-i+1] =np.mean(PE) - np.mean(PS)
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out

# %%
def isPES(Ir,Tr,c) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Coh"+c+"-Final200Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PE = []
        PS=[]
        for j in range(1,len( df.RTs)-1,1):
            if df.LastTrial[j-1]<0:
                PE.append(df.RTs[j])
            else :
                PS.append(df.RTs[j])

        
        PES[i-1] =np.mean(PE) - np.mean(PS)
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out


def isPIA(Ir,Tr,c) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Coh"+c+"-Final200Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE = []
        PS=[]
        for j in range(1,len( df.RTs)-1,1):
            if df.LastTrial[j-1]<0:
                PE.append(df.NotError[j])
            else :
                PS.append(df.NotError[j])

        
        PES[i-1] =np.mean(PE) - np.mean(PS)
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out

# %% [markdown]
# ## TauCD = 200, Fixed Tr=500

# %%
# analysis of the sequential stuff
# find the mask

#mask : 0,1
#1,0

i=1
Tr="500"
c = clist[19]
Ir=Irlist[1]
df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Coh"+c+"-Final200Exp{}-T".format(i)+Tr+"-Ir"+Ir+".csv")

print(df)
# Out:
#        RTs  NotError  Distri     DiffS         S1         S2  LastTrial
# 0      378         1      19 -0.220964  19.958307   3.609461          0
# 1      616         1     -19  0.116902   4.156206  18.854100          1
# 2      682         1      19 -0.158400  22.954394   4.298898          1
# 3      178         1      19 -0.300586  19.981763   0.536397          1
# 4      588        -1     -19 -0.240481  14.396412   3.862123          1
# 5      228         1      19 -0.257562  16.597263   3.438937         -1
# 6      522         1     -19  0.218729   1.799810  23.981822          1
# 7      202         1     -19  0.330715   3.492153  21.625733          1
# 8      352        -1      19  0.248826   1.588950  21.373247          1
# 9      194         1     -19  0.306022   1.596029  17.357344         -1
# 10     550        -1      19  0.195734   4.193216  18.809849          1
# 11     186         1     -19  0.355614   1.714209  21.463600         -1
# ...

# %%
DiagPhase200 = np.zeros((30,20))
Tr=500
for i in range(0,30,1):
    Ir=Irlist[i+2]
    for j in range(0,len(clist),1):
        DiagPhase200[i,j]=isPES(Ir,Tr,clist[j])
        

#for i in range(0,6,1):
 #   Ir=Irlist[17+i]
  #  for j in range(0,len(clist),1):
   #     DiagPhase200[i+9,j]=isPES(Ir,Tr,clist[j])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:36: InstabilityWarning: BCa acceleration values for indexes (array([0]),) were undefined. Statistic values were likely all equal. Affected CI will be inaccurate.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:36: InstabilityWarning: Some values were NaN; results are probably unstable (all values were probably equal)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:36: InstabilityWarning: BCa acceleration values for indexes (array([0]),) were undefined. Statistic values were likely all equal. Affected CI will be inaccurate.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:36: InstabilityWarning: Some values were NaN; results are probably unstable (all values were probably equal)
# ...

# %%
#DP200=DiagPhase200
DiagPhase200[0:16,:]=DP200

# %%
import seaborn as sns; sns.set()
sns.set(style="white")

mask = np.zeros_like(DiagPhase200,dtype=np.bool)
#mask[0:3,:] = True
#mask[3,0:10] = True
#mask[2,19] = False
#mask[1,19] = False

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(DiagPhase200, mask=mask, cmap=cmap,center=0,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('PES Tr=500, relax = 200')     
#plt.savefig("P2D200.svg")
plt.show()

# %%
# Same Stuff with PIA
DiagPhasePIA200 = np.zeros((16,20))
Tr=500
for i in range(0,16,1):
    Ir=Irlist[i]
    for j in range(0,len(clist),1):
        DiagPhasePIA200[i,j]=isPIA(Ir,Tr,clist[j])

# %%
#DPIA200 = DiagPhasePIA200
    
DiagPhasePIA200[0:16,:] =DPIA200

# %%
import seaborn as sns; sns.set()
sns.set(style="white")

mask = np.zeros_like(DiagPhasePIA200,dtype=np.bool)
mask[0:3,:] = True
mask[3,0:10] = True
mask[2,19] = False
mask[1,19] = False

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(DiagPhasePIA200, mask=mask, cmap=cmap,center=0,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('PIA Tr=500, relax = 200')     
plt.savefig("D2P200PIA.svg")
plt.show()

# %% [markdown]
# ## Tr=500 and TauCD=500

# %%
# finding the mask .....
i=1
Tr="500"
c = clist[19]
Ir=Irlist[0]
df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Coh"+c+"-Final500Exp{}-T".format(i)+Tr+"-Ir"+Ir+".csv")

print(df)
# Out:
#        RTs  NotError  Distri     DiffS         S1         S2  LastTrial
# 0      556         1     -19  0.241376   2.232562  16.240326          0
# 1     1074         1      19 -0.094884  15.651669   8.170250          1
# 2      404         1      19 -0.332773  20.498065   1.133039          1
# 3      234         1      19 -0.316133  18.342502   3.111577          1
# 4      746        -1     -19 -0.127252  16.004176   9.597193          1
# 5      466         1     -19  0.303667   2.779548  19.694551         -1
# 6      660         1      19 -0.239359  22.208322   2.427965          1
# 7     1094        -1     -19 -0.180549  19.252100   3.837027          1
# 8      552         1     -19  0.252132   3.833257  18.310087         -1
# 9      808        -1      19  0.143628   8.077311  16.349847          1
# 10     460         1      19 -0.331871  18.411784   3.502855         -1
# 11     224         1      19 -0.358318  20.243497   0.906140          1
# ...

# %%
def isPES500(Ir,Tr,c) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Coh"+c+"-Final500Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PES[i-1] =PE.RTs.mean() - PS.RTs.mean()
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out


def isPIA500(Ir,Tr,c) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatemp/Coh"+c+"-Final500Exp{}-T{}-Ir".format(i,Tr)+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PES[i-1] =PE.NotError.mean() - PS.NotError.mean()
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out

# %%
DiagPPhase500 = np.zeros((16,20))
Tr=500
for i in range(0,16,1):
    Ir=Irlist[i]
    for j in range(0,len(clist),1):
        DiagPPhase500[i,j]=isPIA500(Ir,Tr,clist[j])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:27: InstabilityWarning: BCa acceleration values for indexes (array([0]),) were undefined. Statistic values were likely all equal. Affected CI will be inaccurate.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:27: InstabilityWarning: Some values were NaN; results are probably unstable (all values were probably equal)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:27: InstabilityWarning: BCa acceleration values for indexes (array([0]),) were undefined. Statistic values were likely all equal. Affected CI will be inaccurate.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:27: InstabilityWarning: Some values were NaN; results are probably unstable (all values were probably equal)
# ...

# %%
mask = np.zeros_like(DiagPPhase500,dtype=np.bool)
mask[1:4,0:6] = True
mask[0,0:19] = True

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(DiagPPhase500, mask=mask, cmap=cmap,center=0,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})
plt.savefig("DPPIA500.svg")
plt.title('PES Tr=500, relax = 200')
# Out:
# Text(0.5,1,u'PES Tr=500, relax = 200')

# %% [markdown]
# ## Coh=10 and Taucd=200

# %%
Trlist=["500.0",
"1000.0",
"1500.0",
"2000.0",
"2500.0",
"3000.0",
"3500.0",
"4000.0",
"4500.0",
"5000.0"
]

def isPES_Cohfixed(Ir,Tr) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/media/kevin/My Passport/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatempCoh10/Coh10-Final200Exp{}-T".format(i)+Tr+"-Ir"+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PES[i-1] =PE.RTs.mean() - PS.RTs.mean()
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out

def isPIA_Cohfixed(Ir,Tr) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/media/kevin/My Passport/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatempCoh10/Coh10-Final200Exp{}-T".format(i)+Tr+"-Ir"+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PES[i-1] =PE.NotError.mean() - PS.NotError.mean()
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out

# %%
Irlist=['0.02',
        '0.025714285714285714',
"0.03",
"0.032413793103448274",
"0.03482758620689655",
"0.037241379310344824",
"0.039655172413793106",
"0.04206896551724138",
"0.04448275862068966",
"0.04689655172413793",
"0.04931034482758621",
"0.05172413793103448",
"0.05413793103448276",
"0.05655172413793103",
"0.05896551724137931",
"0.06137931034482759",
"0.06379310344827586",
"0.06620689655172414",
"0.06862068965517241",
"0.07103448275862069",
"0.07344827586206897",
"0.07586206896551724",
"0.07827586206896552",
"0.08068965517241379",
"0.08310344827586207",
"0.08551724137931034",
"0.08793103448275862",
"0.09034482758620689",
"0.09275862068965517",
"0.09517241379310344",
"0.09758620689655173",
"0.1"

]
i=1
Tr="5000.0"

Ir=Irlist[2]
df=pd.read_csv("/home/kevin/Documents/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatempCoh10/Coh10-Final200Exp{}-T".format(i)+Tr+"-Ir"+Ir+".csv")

print(df)
# Out:
#       RTs  NotError  Distri     DiffS         S1         S2  LastTrial
# 0     522         1     -10  0.233532   1.990372  19.369924          0
# 1     426         1     -10  0.206786   2.005257  18.217622          1
# 2     616         1     -10  0.269602   4.187129  21.584056          1
# 3     410         1     -10  0.349007   2.876253  22.017744          1
# 4     320         1     -10  0.282215   3.734251  22.214567          1
# 5     376         1      10 -0.218211  15.833055   2.330397          1
# 6     506         1     -10  0.253797   0.925851  21.253850          1
# 7     432         1     -10  0.250762   5.670152  19.529624          1
# 8     708         1     -10  0.281200   1.897539  21.587509          1
# 9     588         1     -10  0.224429   3.736244  19.016296          1
# 10    454         1      10 -0.321428  18.282598   4.685946          1
# 11    466         1      10 -0.260363  21.030634   1.776301          1
# ...

# %%
DiagPhase200Coh10 = np.zeros((10,10))

for i in range(0,10,1):
    Ir=Irlist[i]
    for j in range(0,len(Trlist),1):
        Tr=Trlist[j]
        DiagPhase200Coh10[i,j]=isPES_Cohfixed(Ir,Tr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-20497e23cc9f> in <module>()
#       5     for j in range(0,len(Trlist),1):
#       6         Tr=Trlist[j]
# ----> 7         DiagPhase200Coh10[i,j]=isPES_Cohfixed(Ir,Tr)
#       8
#
# <ipython-input-22-6e7a372c0e5a> in isPES_Cohfixed(Ir, Tr)
#      14     PES=np.zeros(50)
#      15     for i in range(1,51,1):
# ---> 16         df=pd.read_csv("/media/kevin/My Passport/Boulot/Projects/SequentialDecisionMaking/data/PhaseDiag/datatempCoh10/Coh10-Final200Exp{}-T".format(i)+Tr+"-Ir"+Ir+".csv")
#      17
#      18         PE=df.query('LastTrial<0')
#
# ...

# %%
import seaborn as sns; sns.set()
sns.set(style="white")

df = pd.DataFrame(data=DiagPhase200Coh10,columns=Trlist)

mask = np.zeros_like(DiagPhase200Coh10,dtype=np.bool)
DiagPhase200Coh10[0:3,0] = 0
DiagPhase200Coh10[0:1,1:5] = 0
DiagPhase200Coh10[0:2,:]=0
mask[0:3,0] = True
mask[0:1,1:5] = True
mask[0:2,:]=True
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(df, mask=mask, cmap=cmap,center=0,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})


plt.title('Coh 10, relax = 200') 
plt.show()

# %%
DiagPhase500Coh10 = np.zeros((7,10))

for i in range(0,7,1):
    Ir=Irlist[i]
    for j in range(0,len(Trlist),1):
        Tr=Trlist[j]
        DiagPhase500Coh10[i,j]=isPIA_Cohfixed(Ir,Tr)

# %%
import seaborn as sns; sns.set()
sns.set(style="white")

df = pd.DataFrame(data=DiagPhase500Coh10,columns=Trlist)

mask = np.zeros_like(DiagPhase500Coh10,dtype=np.bool)
DiagPhase500Coh10[0:3,0] = 0
DiagPhase500Coh10[0:1,1:5] = 0
DiagPhase500Coh10[0:2,:]=0
mask[0:3,0] = True
mask[0:1,1:5] = True
mask[0:2,:]=True

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(df, mask=mask, cmap=cmap,center=0,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})


plt.title('Coh 10, relax = 200')
# Out:
# Text(0.5,1,u'Coh 10, relax = 200')

# %%
import seaborn as sns; sns.set()
sns.set(style="white")

df = pd.DataFrame(data=DiagPhase500Coh10,columns=Trlist)

mask = np.zeros_like(DiagPhase500Coh10,dtype=np.bool)
mask[0,0:1] = True

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(df, mask=mask, cmap=cmap,vmax=1,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})


plt.title('Coh 10, relax = 200')
# Out:
# Text(0.5,1,u'Coh 10, relax = 200')

# %% [markdown]
# # Variation Tr et Coh

# %%
def isPESnew(Ir,Tr,c) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/media/kevin/My Passport/Boulot/Projects/SequentialDecisionMaking/src/data035/Coh"+c+"-Final500Exp{}-T".format(i,Tr)+Tr+"-Ir"+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PES[i-1] =PE.RTs.mean() - PS.RTs.mean()
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out


def isPIAnew(Ir,Tr,c) :
    PES=np.zeros(50)
    for i in range(1,51,1):
        df=pd.read_csv("/media/kevin/My Passport/Boulot/Projects/SequentialDecisionMaking/src/data035/Coh"+c+"-Final200Exp{}-T".format(i,Tr)+Tr+"-Ir"+Ir+".csv")

        PE=df.query('LastTrial<0')
        PS=df.query('LastTrial>0')

        PES[i-1] =PE.NotError.mean() - PS.NotError.mean()
    CIs = bootstrap.ci(data=PES, statfunction=scipy.mean,n_samples=20000)  
    if np.sign(CIs[0])==np.sign(CIs[1]):
        out = np.mean(PES)#np.sign(CIs[0])
    else :
        out = 0
    return out

# %%
clist2=["0.01",
"2.12",
"4.23",
"6.34",
"8.45",
"10.56",
"12.67",
"14.78",
"16.89",
"19.0"
]

Trlist2=["200.0",
"400.0",
"600.0",
"800.0",
"1000.0",
"1200.0",
"1400.0",
"1600.0",
"1800.0",
"2000.0"
]

Ir="0.035"
DiagPhaseRR035 = 1*np.zeros((10,10))
Tr=500

for i in range(0,10,1):
    Tr=Trlist2[i]
    for j in range(0,len(clist2),1):
        DiagPhaseRR035[i,j]=isPIAnew(Ir,Tr,clist2[j])

# %%
# need to clean datas with the mask !!

# %%
import seaborn as sns; sns.set()
sns.set(style="white")

df = pd.DataFrame(data=DiagPhaseRR035)

mask = np.zeros_like(DiagPhaseRR035,dtype=np.bool)
mask[0,:] = True

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(df, mask=mask, cmap=cmap,center=0,xticklabels=2,yticklabels=3, linewidths=.5, cbar_kws={"shrink": .5})


plt.title('Ir035, relax = 200')   
plt.savefig("DPTvarPIA.svg")
plt.show()
