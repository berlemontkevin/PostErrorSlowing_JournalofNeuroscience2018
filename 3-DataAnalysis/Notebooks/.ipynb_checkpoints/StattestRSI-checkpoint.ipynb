# %%
import pandas as pd
from pandas import DataFrame

import statistics as stat

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import scipy  
#import scikits.bootstrap as bootstrap

# %%
from scipy import stats
stats.ks_2samp(dfalt.RTAlt, dfrep.RTRep)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9272e7f2e6d9> in <module>()
#       1 from scipy import stats
# ----> 2 stats.ks_2samp(dfalt.RTAlt, dfrep.RTRep)
#
# NameError: name 'dfalt' is not defined

# %%
import dcor
dcor.homogeneity.energy_test(dfalt9.RTAlt, dfrep9.RTRep,num_resamples=7)

# %%
from scipy.stats import energy_distance
Ilist=["0.035","0.04","0.05","0.06","0.07","0.08","0.09","0.1"]
elist0=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T500-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist0.append(energy_distance(dfalt.RTs, dfrep.RTs))
elist01=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T1000-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist01.append(energy_distance(dfalt.RTs, dfrep.RTs))
elist=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T1500-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist.append(energy_distance(dfalt.RTs, dfrep.RTs))
elist2=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T2000-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist2.append(energy_distance(dfalt.RTs, dfrep.RTs))
elist3=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T2500-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist3.append(energy_distance(dfalt.RTs, dfrep.RTs))
    
elist4=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T5000-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist4.append(energy_distance(dfalt.RTs, dfrep.RTs))
elist5=[]
for I in Ilist:
    df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T10000-Ir"+I+".csv")
    dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
    dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
    elist5.append(energy_distance(dfalt.RTs, dfrep.RTs))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-3b3a03227fb8> in <module>()
#       3 elist0=[]
#       4 for I in Ilist:
# ----> 5     df = pd.read_csv("/home/kevin/Documents/1 - PhD Projects/1 - Sequential Decision making/3-SequentialEffects/2-Data/testsAltRep/EnergyTest/1000RepAlt-T500-Ir"+I+".csv")
#       6     dfalt= df[np.sign(df.LastCoh) == -np.sign(df.Distri)]
#       7     dfrep=df[np.sign(df.LastCoh) == np.sign(df.Distri)]
#
# ...

# %%
import seaborn as sns
sns.set(style="whitegrid")
sns.despine()
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 4})
sns.set_palette("colorblind")
f, ax = plt.subplots(figsize=(11, 9))
plt.plot(Ilist,elist0)
plt.plot(Ilist,elist)
plt.plot(Ilist,elist2)
plt.plot(Ilist,elist3)
plt.plot(Ilist,elist4)
plt.plot(Ilist,elist5)
#plt.xlim([0.035,0.1])
#plt.ylim([0.0,0.4])

#plt.savefig("RSIinf.svg")
# Out:
# [3.8176542057988052,
#  3.2102367352917569,
#  2.4803579257304738,
#  1.7204893792340679,
#  1.1094827925091493,
#  1.5001366744365472,
#  0.79929167504497045,
#  1.0880804587310529]
